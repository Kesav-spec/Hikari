# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import json

# %% [markdown]
# ### Handle Anime Data

# %%
anime_df = pd.read_json("../dataset/anime.json")

# %%
anime_df
# Out:
#          _id    malId  kitsuId                            title  \
# 0          1      1.0      1.0                     Cowboy Bebop
# 1          2      5.0      2.0  Cowboy Bebop: Tengoku no Tobira
# 2          3      6.0      3.0                           Trigun
# 3          4      7.0      4.0               Witch Hunter Robin
# 4          5      8.0      5.0                   Bouken Ou Beet
# ...      ...      ...      ...                              ...
# 24071  24087  57799.0      NaN     Bai Bian Xiao Ba 12th Season
# 24072  24088  57801.0      NaN               Bai She 3: Fusheng
# 24073  24089  57810.0      NaN                Shoushimin Series
# 24074  24090  57820.0      NaN    Kamitsubaki-shi Kensetsuchuu.
# 24075  24091  57827.0      NaN         Mashin Souzou Den Wataru
#
#                             en                             enjp  \
# 0                 Cowboy Bebop                     Cowboy Bebop
# 1      Cowboy Bebop: The Movie  Cowboy Bebop: Tengoku no Tobira
# 2                       Trigun                           Trigun
# 3           Witch Hunter Robin               Witch Hunter Robin
# 4       Beet the Vandel Buster                   Bouken Ou Beet
# ...                        ...                              ...
# 24071                     None     Bai Bian Xiao Ba 12th Season
# 24072                     None               Bai She 3: Fusheng
# 24073                     None                Shoushimin Series
# 24074                     None    Kamitsubaki-shi Kensetsuchuu.
# 24075                     None         Mashin Souzou Den Wataru
#
#                                      jp                             slug  \
# 0                             カウボーイビバップ                     Cowboy_Bebop
# 1                        カウボーイビバップ 天国の扉  Cowboy_Bebop__Tengoku_no_Tobira
# 2                                 トライガン                           Trigun
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)               Witch_Hunter_Robin
# 4                                冒険王ビィト                   Bouken_Ou_Beet
# ...                                 ...                              ...
# 24071                         百变校巴 第12季     Bai_Bian_Xiao_Ba_12th_Season
# 24072                            白蛇3：浮生               Bai_She_3__Fusheng
# 24073                           小市民シリーズ                Shoushimin_Series
# 24074                           神椿市建設中.     Kamitsubaki-shi_Kensetsuchuu
# 24075                          魔神創造伝ワタル         Mashin_Souzou_Den_Wataru
#
#                                                   poster   type  ...  \
# 0      https://media.kitsu.io/anime/poster_images/1/o...     TV  ...
# 1      https://media.kitsu.io/anime/poster_images/2/o...  Movie  ...
# 2      https://media.kitsu.io/anime/3/poster_image/d4...     TV  ...
# 3      https://media.kitsu.io/anime/poster_images/4/o...     TV  ...
# 4      https://media.kitsu.io/anime/poster_images/5/o...     TV  ...
# ...                                                  ...    ...  ...
# 24071  https://cdn.myanimelist.net/images/anime/1226/...     TV  ...
# 24072  https://cdn.myanimelist.net/images/anime/1448/...  Movie  ...
# 24073  https://cdn.myanimelist.net/images/anime/1697/...     TV  ...
# 24074  https://cdn.myanimelist.net/images/anime/1653/...     TV  ...
# 24075  https://cdn.myanimelist.net/images/anime/1275/...     TV  ...
#
#           endDate                        rating episodeCount  \
# 0      1999-04-24  R - 17+ Violence & Profanity         26.0
# 1      2001-09-01  R - 17+ Violence & Profanity          1.0
# 2      1998-09-30     PG-13 - Teens 13 or older         26.0
# 3      2002-12-25     PG-13 - Teens 13 or older         26.0
# 4      2005-09-29     PG-13 - Teens 13 or older         52.0
# ...           ...                           ...          ...
# 24071        None                          None         26.0
# 24072        None                          None          1.0
# 24073        None                          None          NaN
# 24074        None                          None          NaN
# 24075        None                          None          NaN
#
#                  studio score popularity    likes  \
# 0             [Sunrise]  87.5  1832322.0  81086.0
# 1               [Bones]  83.8   371915.0   1545.0
# 2            [Madhouse]  82.2   750793.0  15706.0
# 3             [Sunrise]  72.4   115033.0    638.0
# 4      [Toei Animation]  69.3    15300.0     15.0
# ...                 ...   ...        ...      ...
# 24071              None   NaN       15.0      NaN
# 24072              None   NaN      346.0      NaN
# 24073     [Lapin Track]   NaN     1937.0      NaN
# 24074              None   NaN        1.0      NaN
# 24075              None   NaN        1.0      NaN
#
#                                              recommended         runtime  \
# 0      [{'_id': 874, 'title': 'Uchuu Kaizoku Captain ...            None
# 1      [{'_id': 4726, 'title': 'Code Geass: Boukoku n...  1 Hour 55 Mins
# 2      [{'_id': 8299, 'title': 'God Eater', 'slug': '...            None
# 3      [{'_id': 13141, 'title': 'Mahouka Koukou no Re...            None
# 4      [{'_id': 13947, 'title': 'Kimetsu no Yaiba: Yu...            None
# ...                                                  ...             ...
# 24071                                                 []            None
# 24072                                                 []            None
# 24073                                                 []            None
# 24074                                                 []            None
# 24075                                                 []            None
#
#          source
# 0      Original
# 1      Original
# 2         Manga
# 3      Original
# 4         Manga
# ...         ...
# 24071  Original
# 24072     Other
# 24073     Novel
# 24074     Other
# 24075  Original
#
# [24076 rows x 26 columns]

# %% [markdown]
# Remove rows without malId for consistency.

# %%
anime_df.dropna(axis=0, subset="malId", inplace=True)
anime_df.drop_duplicates(subset="malId", inplace=True)

# %% [markdown]
# Remove unnecessary columns.

# %%
anime_df.drop(columns=["slug", "recommended", "runtime"], inplace=True)

# %% [markdown]
# ### Handle Anime Tags

# %%
with open("../dataset/animetags.json", "r", encoding="utf-8") as file:
    animetags = json.load(file)
    animetags = animetags["data"]

# %% [markdown]
# Get the list of valid tags. Adult tags, tags with typo, unnecessary tags, etc are removed from this list.

# %%
valid_tags = set(open("validTags.txt").read().split(","))

# %% [markdown]
# A function that gets the mal id from a list of source links.

# %%
def get_mal_id(links):
    for link in links:
        if "myanimelist" in link:
            return link.rsplit("/", 1)[-1]

# %% [markdown]
# A function to create a map of anime id and its respective tags.

# %%
def extract_tags(data):
    tags = {}
    for anime in data:
        mal_id = get_mal_id(anime["sources"])
        if mal_id:
            tags[mal_id] = ", ".join([x for x in anime["tags"] if x in valid_tags])

    return tags

# %%
tags = extract_tags(animetags)

# %% [markdown]
# Create a new dataframe for the tags.

# %%
tags_df = pd.DataFrame(tags.items(), columns=["malId", "tags"])
tags_df.malId = tags_df.malId.astype(float)

# %% [markdown]
# ### Prepare Final Dataset

# %% [markdown]
# Merge the anime data with tags.

# %%
df = pd.merge(anime_df, tags_df, on="malId", how="inner")

# %%
df
# Out:
#          _id    malId  kitsuId                                    title  \
# 0          1      1.0      1.0                             Cowboy Bebop
# 1          2      5.0      2.0          Cowboy Bebop: Tengoku no Tobira
# 2          3      6.0      3.0                                   Trigun
# 3          4      7.0      4.0                       Witch Hunter Robin
# 4          5      8.0      5.0                           Bouken Ou Beet
# ...      ...      ...      ...                                      ...
# 21418  24074  57478.0      NaN                           Kuramerukagari
# 21419  24075  57538.0      NaN  Sai-Kyo-Oh! Zukan: The Ultimate Battles
# 21420  24076  57677.0      NaN                              Bibliomania
# 21421  24078  57702.0      NaN                            Zaiyuki Pilot
# 21422  24079  57765.0      NaN              Bai Bian Xiao Ba 8th Season
#
#                             en                                     enjp  \
# 0                 Cowboy Bebop                             Cowboy Bebop
# 1      Cowboy Bebop: The Movie          Cowboy Bebop: Tengoku no Tobira
# 2                       Trigun                                   Trigun
# 3           Witch Hunter Robin                       Witch Hunter Robin
# 4       Beet the Vandel Buster                           Bouken Ou Beet
# ...                        ...                                      ...
# 21418                     None                           Kuramerukagari
# 21419                     None  Sai-Kyo-Oh! Zukan: The Ultimate Battles
# 21420                     None                              Bibliomania
# 21421                     None                            Zaiyuki Pilot
# 21422                     None              Bai Bian Xiao Ba 8th Season
#
#                                      jp  \
# 0                             カウボーイビバップ
# 1                        カウボーイビバップ 天国の扉
# 2                                 トライガン
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                                冒険王ビィト
# ...                                 ...
# 21418                           くらめるかがり
# 21419      最強王図鑑 ～The Ultimate Battles～
# 21420                       BIBLIOMANIA
# 21421                             ザイユウキ
# 21422                          百变校巴 第8季
#
#                                                   poster   type  \
# 0      https://media.kitsu.io/anime/poster_images/1/o...     TV
# 1      https://media.kitsu.io/anime/poster_images/2/o...  Movie
# 2      https://media.kitsu.io/anime/3/poster_image/d4...     TV
# 3      https://media.kitsu.io/anime/poster_images/4/o...     TV
# 4      https://media.kitsu.io/anime/poster_images/5/o...     TV
# ...                                                  ...    ...
# 21418  https://cdn.myanimelist.net/images/anime/1716/...  Movie
# 21419  https://cdn.myanimelist.net/images/anime/1229/...     TV
# 21420  https://cdn.myanimelist.net/images/anime/1019/...  Movie
# 21421  https://cdn.myanimelist.net/images/anime/1167/...    ONA
# 21422  https://cdn.myanimelist.net/images/anime/1918/...     TV
#
#                                                 synopsis  ...   startDate  \
# 0      Crime is timeless. By the year 2071, humanity ...  ...  1998-04-03
# 1      Another day, another bounty—such is the life o...  ...  2001-09-01
# 2      Vash the Stampede is the man with a $$60,000,0...  ...  1998-04-01
# 3      Robin Sena is a powerful craft user drafted in...  ...  2002-07-03
# 4      It is the dark century and the people are suff...  ...  2004-09-30
# ...                                                  ...  ...         ...
# 21418  This is a story that weaves together people an...  ...  2024-04-12
# 21419                                               None  ...  2024-01-06
# 21420                                               None  ...  2013-04-06
# 21421  Pilot version of the upcoming Zaiyuki series r...  ...  2023-12-30
# 21422                                               None  ...        None
#
#           endDate                        rating episodeCount  \
# 0      1999-04-24  R - 17+ Violence & Profanity         26.0
# 1      2001-09-01  R - 17+ Violence & Profanity          1.0
# 2      1998-09-30     PG-13 - Teens 13 or older         26.0
# 3      2002-12-25     PG-13 - Teens 13 or older         26.0
# 4      2005-09-29     PG-13 - Teens 13 or older         52.0
# ...           ...                           ...          ...
# 21418        None                           NaN          1.0
# 21419        None                           NaN          NaN
# 21420        None                           NaN          1.0
# 21421        None                           NaN          1.0
# 21422        None                           NaN         26.0
#
#                  studio score popularity    likes    source  \
# 0             [Sunrise]  87.5  1832322.0  81086.0  Original
# 1               [Bones]  83.8   371915.0   1545.0  Original
# 2            [Madhouse]  82.2   750793.0  15706.0     Manga
# 3             [Sunrise]  72.4   115033.0    638.0  Original
# 4      [Toei Animation]  69.3    15300.0     15.0     Manga
# ...                 ...   ...        ...      ...       ...
# 21418              None   NaN       22.0      NaN  Original
# 21419     [OLM Digital]   NaN       71.0      NaN      Book
# 21420              None   NaN       31.0      1.0  Original
# 21421  [Village Studio]   NaN       36.0      NaN  Original
# 21422              None   NaN       24.0      NaN  Original
#
#                                                   tags_y
# 0      action, adult cast, adventure, amnesia, anti-h...
# 1      action, adult cast, adventure, amnesia, anti-h...
# 2      action, adult cast, adventure, alien, aliens, ...
# 3      action, asia, bionic powers, coming of age, co...
# 4      action, adventure, alternative world, based on...
# ...                                                  ...
# 21418  detective, fantasy, mystery, original work, sc...
# 21419                                             action
# 21420  alternate universe, avant garde, cosmic horror...
# 21421           action, adventure, fantasy, supernatural
# 21422                     anthropomorphic, fantasy, kids
#
# [21423 rows x 24 columns]

# %% [markdown]
# #### Format the columns

# %% [markdown]
# Convert column types

# %%
df["malId"] = df["malId"].astype(pd.Int64Dtype(), errors="ignore")
df["episodeCount"] = pd.to_numeric(df["episodeCount"], errors="coerce").astype(
    pd.Int64Dtype()
)
df["popularity"] = pd.to_numeric(df["popularity"], errors="coerce").astype(
    pd.Int64Dtype()
)

string_columns = [
    "title",
    "en",
    "enjp",
    "jp",
    "poster",
    "type",
    "synopsis",
    "season",
    "startDate",
    "endDate",
    "rating",
    "status",
    "source",
]
df[string_columns] = df[string_columns].astype(str)

# %% [markdown]
# Drop unnecessary columns

# %%
df.drop(["kitsuId", "tags_x"], axis=1, inplace=True)

# %% [markdown]
# Convert array values to string

# %%
df["genres"] = df["genres"].apply(lambda x: x and ", ".join(list(x)))
df["studio"] = df["studio"].apply(lambda x: x and ", ".join(list(x)))

# %% [markdown]
# Rename tags column

# %%
df.rename(columns={"tags_y": "tags"}, inplace=True)

# %%
df
# Out:
#          _id  malId                                    title  \
# 0          1      1                             Cowboy Bebop
# 1          2      5          Cowboy Bebop: Tengoku no Tobira
# 2          3      6                                   Trigun
# 3          4      7                       Witch Hunter Robin
# 4          5      8                           Bouken Ou Beet
# ...      ...    ...                                      ...
# 21418  24074  57478                           Kuramerukagari
# 21419  24075  57538  Sai-Kyo-Oh! Zukan: The Ultimate Battles
# 21420  24076  57677                              Bibliomania
# 21421  24078  57702                            Zaiyuki Pilot
# 21422  24079  57765              Bai Bian Xiao Ba 8th Season
#
#                             en                                     enjp  \
# 0                 Cowboy Bebop                             Cowboy Bebop
# 1      Cowboy Bebop: The Movie          Cowboy Bebop: Tengoku no Tobira
# 2                       Trigun                                   Trigun
# 3           Witch Hunter Robin                       Witch Hunter Robin
# 4       Beet the Vandel Buster                           Bouken Ou Beet
# ...                        ...                                      ...
# 21418                     None                           Kuramerukagari
# 21419                     None  Sai-Kyo-Oh! Zukan: The Ultimate Battles
# 21420                     None                              Bibliomania
# 21421                     None                            Zaiyuki Pilot
# 21422                     None              Bai Bian Xiao Ba 8th Season
#
#                                      jp  \
# 0                             カウボーイビバップ
# 1                        カウボーイビバップ 天国の扉
# 2                                 トライガン
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                                冒険王ビィト
# ...                                 ...
# 21418                           くらめるかがり
# 21419      最強王図鑑 ～The Ultimate Battles～
# 21420                       BIBLIOMANIA
# 21421                             ザイユウキ
# 21422                          百变校巴 第8季
#
#                                                   poster   type  \
# 0      https://media.kitsu.io/anime/poster_images/1/o...     TV
# 1      https://media.kitsu.io/anime/poster_images/2/o...  Movie
# 2      https://media.kitsu.io/anime/3/poster_image/d4...     TV
# 3      https://media.kitsu.io/anime/poster_images/4/o...     TV
# 4      https://media.kitsu.io/anime/poster_images/5/o...     TV
# ...                                                  ...    ...
# 21418  https://cdn.myanimelist.net/images/anime/1716/...  Movie
# 21419  https://cdn.myanimelist.net/images/anime/1229/...     TV
# 21420  https://cdn.myanimelist.net/images/anime/1019/...  Movie
# 21421  https://cdn.myanimelist.net/images/anime/1167/...    ONA
# 21422  https://cdn.myanimelist.net/images/anime/1918/...     TV
#
#                                                 synopsis         status  ...  \
# 0      Crime is timeless. By the year 2071, humanity ...       Finished  ...
# 1      Another day, another bounty—such is the life o...       Finished  ...
# 2      Vash the Stampede is the man with a $$60,000,0...       Finished  ...
# 3      Robin Sena is a powerful craft user drafted in...       Finished  ...
# 4      It is the dark century and the people are suff...       Finished  ...
# ...                                                  ...            ...  ...
# 21418  This is a story that weaves together people an...  Not Yet Aired  ...
# 21419                                               None         Airing  ...
# 21420                                               None       Finished  ...
# 21421  Pilot version of the upcoming Zaiyuki series r...       Finished  ...
# 21422                                               None       Finished  ...
#
#         startDate     endDate                        rating episodeCount  \
# 0      1998-04-03  1999-04-24  R - 17+ Violence & Profanity           26
# 1      2001-09-01  2001-09-01  R - 17+ Violence & Profanity            1
# 2      1998-04-01  1998-09-30     PG-13 - Teens 13 or older           26
# 3      2002-07-03  2002-12-25     PG-13 - Teens 13 or older           26
# 4      2004-09-30  2005-09-29     PG-13 - Teens 13 or older           52
# ...           ...         ...                           ...          ...
# 21418  2024-04-12        None                           nan            1
# 21419  2024-01-06        None                           nan         <NA>
# 21420  2013-04-06        None                           nan            1
# 21421  2023-12-30        None                           nan            1
# 21422        None        None                           nan           26
#
#                studio  score popularity    likes    source  \
# 0             Sunrise   87.5    1832322  81086.0  Original
# 1               Bones   83.8     371915   1545.0  Original
# 2            Madhouse   82.2     750793  15706.0     Manga
# 3             Sunrise   72.4     115033    638.0  Original
# 4      Toei Animation   69.3      15300     15.0     Manga
# ...               ...    ...        ...      ...       ...
# 21418            None    NaN         22      NaN  Original
# 21419     OLM Digital    NaN         71      NaN      Book
# 21420            None    NaN         31      1.0  Original
# 21421  Village Studio    NaN         36      NaN  Original
# 21422            None    NaN         24      NaN  Original
#
#                                                     tags
# 0      action, adult cast, adventure, amnesia, anti-h...
# 1      action, adult cast, adventure, amnesia, anti-h...
# 2      action, adult cast, adventure, alien, aliens, ...
# 3      action, asia, bionic powers, coming of age, co...
# 4      action, adventure, alternative world, based on...
# ...                                                  ...
# 21418  detective, fantasy, mystery, original work, sc...
# 21419                                             action
# 21420  alternate universe, avant garde, cosmic horror...
# 21421           action, adventure, fantasy, supernatural
# 21422                     anthropomorphic, fantasy, kids
#
# [21423 rows x 22 columns]

# %% [markdown]
# ### Save dataset

# %%
df.to_json("data.json", orient="records")

# %% [markdown]
# ### Extra Code

# %% [markdown]
# Get the list of unique tags from the tags dataset

# %%
# all_tags = [tag.strip() for tags in merged_df["tags_y"] for tag in tags.split(",")]

# # Get unique tags
# unique_tags = list(set(all_tags))

# # Write unique tags to a text file
# with open("unique_tags.txt", "w") as file:
#     file.write(",".join(unique_tags))
